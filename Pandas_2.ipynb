# %%
import pandas as pd
import numpy as np

# %%
pd.Series(['a','b','c','d'],index=[3,4,5,6])
# Out:
# 3    a
# 4    b
# 5    c
# 6    d
# dtype: object

# %%
pd.Series({'a': 1, 'b': 2, 'c': 3})
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
import random
pd.Series(np.random.randint(5),index=np.random.rand(5))
# Out:
# 0.351536    0
# 0.840264    0
# 0.791356    0
# 0.063820    0
# 0.684914    0
# dtype: int64

# %%
# loc it does slicing both on rows and col

# You can use only custome indexing

# %% [markdown]
# x.loc[startorw:stoprow:step,startcol:stopcol:step]

# %%
import pandas as pd

# %%
df=pd.read_csv('datasets/citibike_tripdata.csv')

# %%
# use custome indexing only

df.loc[0:4]

# IN this 0 & 4 IS ICLUSIVE
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
new_data=df[0:7]
new_data.index=['a','b','c','d','e','f','g']
new_data
# Out:
#    tripduration            starttime             stoptime  start station id  \
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# c           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# e           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# f           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# g           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
#
#       start station name  end station id end station name  bikeid  \
# a             Harborside            3199     Newport Pkwy   33558
# b               Grand St            3185        City Hall   33593
# c        McGinley Square            3193     Lincoln Park   29217
# d              City Hall            3186    Grove St PATH   29662
# ...

# %%
new_data.loc['a':'e',"tripduration":"stoptime"]
# Out:
#    tripduration            starttime             stoptime
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# c           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# e           303  2018-05-01 04:27:12  2018-05-01 04:32:16

# %%
# reverse the indexing
# new_data.loc['e':'a',"tripduration":"stoptime"]
new_data.loc[::-1,"tripduration":"stoptime"]
# Out:
#    tripduration            starttime             stoptime
# g           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# f           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# e           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# c           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25

# %%
# Complete customization 
new_data.loc[['a','c','d'],['starttime','bikeid']]
# Out:
#              starttime  bikeid
# a  2018-05-01 00:04:47   33558
# c  2018-05-01 01:31:29   29217
# d  2018-05-01 02:03:29   29662

# %%
new_data.loc(['e','c','d','g'],['stoptime','bikeid','start station id'])

# the difference is bracket
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/2079758417.py in <module>
# ----> 1 new_data.loc(['e','c','d','g'],['stoptime','bikeid','start station id'])
#       2
#       3 # the difference is bracket
#
# TypeError: __call__() takes from 1 to 2 positional arguments but 3 were given

# %%
new_data.loc[['e','c','d','g'],['stoptime','bikeid','start station id']]

# %%
# only row customized 
new_data.loc[['a','b','d'],'starttime':'bikeid']

# %%
# select column

new_data.loc[new_data["tripduration"]>200]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# c           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# e           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# g           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
#
#       start station name  end station id end station name  bikeid  \
# a             Harborside            3199     Newport Pkwy   33558
# b               Grand St            3185        City Hall   33593
# c        McGinley Square            3193     Lincoln Park   29217
# e            Oakland Ave            3195          Sip Ave   15271
# g  Baldwin at Montgomery            3186    Grove St PATH   33619
#
#                        name_localizedValue    usertype
# a                        Annual Membership  Subscriber
# ...

# %%
new_data[new_data['tripduration']>400]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# g           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
#
#       start station name  end station id end station name  bikeid  \
# b               Grand St            3185        City Hall   33593
# g  Baldwin at Montgomery            3186    Grove St PATH   33619
#
#                     name_localizedValue    usertype
# b                               24 Hour    Customer
# g  Annual Membership from Citi Bike App  Subscriber

# %%
new_data[new_data['start station id']==3681]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
#
#   name_localizedValue  usertype
# b             24 Hour  Customer

# %%
new_data[new_data['start station name']=='Grand St']
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
#
#   name_localizedValue  usertype
# b             24 Hour  Customer

# %%
# get all the Customer data from the 'usertype'
new_data.loc[new_data["usertype"]=="Customer"]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
# d          City Hall            3186    Grove St PATH   29662
#
#   name_localizedValue  usertype
# b             24 Hour  Customer
# d             24 Hour  Customer

# %%
new_data[new_data['bikeid']==33558]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
#
#   start station name  end station id end station name  bikeid  \
# a         Harborside            3199     Newport Pkwy   33558
#
#   name_localizedValue    usertype
# a   Annual Membership  Subscriber

# %%
new_data.loc[new_data["bikeid"]>30000]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# g           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
#
#       start station name  end station id end station name  bikeid  \
# a             Harborside            3199     Newport Pkwy   33558
# b               Grand St            3185        City Hall   33593
# g  Baldwin at Montgomery            3186    Grove St PATH   33619
#
#                     name_localizedValue    usertype
# a                     Annual Membership  Subscriber
# b                               24 Hour    Customer
# g  Annual Membership from Citi Bike App  Subscriber

# %%
# donot use and,or
new_data.loc[new_data["usertype"]=='Customer' and ["bikeid"]>30000]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_2260/1296192729.py in <module>
#       1 # donot use and,or
# ----> 2 new_data.loc[new_data["usertype"]=='Customer' and ["bikeid"]>30000]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# """
# and -- &
# or -- |
#
# """
# use it in the multiple conditioin

# %%
new_data[(new_data['usertype']=="Customer") & (new_data['start station id']>3680)]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
#
#   name_localizedValue  usertype
# b             24 Hour  Customer

# %%
new_data.loc[(new_data['usertype']=='Customer') | (new_data['start station id']>3680)]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
# d          City Hall            3186    Grove St PATH   29662
#
#   name_localizedValue  usertype
# b             24 Hour  Customer
# d             24 Hour  Customer

# %%
# use paranthesis with logic bitwise operation

new_data.loc[(new_data["usertype"]=='Customer') & (new_data["bikeid"]>30000)]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
#
#   name_localizedValue  usertype
# b             24 Hour  Customer

# %%
new_data[(new_data["usertype"]=='Customer') & (new_data["bikeid"]>30000)]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
#
#   name_localizedValue  usertype
# b             24 Hour  Customer

# %%
new_data[(new_data['starttime']== '2018-05-01 01:31:10') | (new_data['end station id']<3080)]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
#
#   start station name  end station id end station name  bikeid  \
# b           Grand St            3185        City Hall   33593
#
#   name_localizedValue  usertype
# b             24 Hour  Customer

# %%
new_data.loc[(new_data['tripduration']>=200) & (new_data["tripduration"]<=1000)]

# %% [markdown]
# ### iloc is opp of loc
# * rows as well as  col
# * only indexing - zero indexing

# %%
# custom indexing fails in iloc[]

new_data.iloc['a':'d']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/1623218892.py in <module>
#       1 # custom indexing fails in iloc[]
#       2
# ----> 3 new_data.iloc['a':'d']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1541
#    1542         if isinstance(key, slice):
# -> 1543             return self._get_slice_axis(key, axis=axis)
#    1544
#    1545         if is_iterator(key):
#
# ...

# %%
# prints 0 to 3 rows
df.iloc[:4]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# 1                                  24 Hour    Customer
# 2  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
# prints 4 rows and 5 col

new_data.iloc[:4,0:5]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# c           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
#
#   start station name
# a         Harborside
# b           Grand St
# c    McGinley Square
# d          City Hall

# %%
# you can  only use zero indexing

# %%
new_data.iloc[0:4,:]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# c           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
#
#   start station name  end station id end station name  bikeid  \
# a         Harborside            3199     Newport Pkwy   33558
# b           Grand St            3185        City Hall   33593
# c    McGinley Square            3193     Lincoln Park   29217
# d          City Hall            3186    Grove St PATH   29662
#
#                        name_localizedValue    usertype
# a                        Annual Membership  Subscriber
# b                                  24 Hour    Customer
# c  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
# no filtering available

new_data.iloc[[0,1,3,4],:4]
# Out:
#    tripduration            starttime             stoptime  start station id
# a           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# d           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# e           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207

# %%
new_data.loc[['a','d'],['bikeid','stoptime']]
# Out:
#    bikeid             stoptime
# a   33558  2018-05-01 00:10:25
# d   29662  2018-05-01 02:06:40

# %%
new_data.iloc[1:3,1:5]
# iloco neeed numeric indexes
# Out:
#              starttime             stoptime  start station id  \
# b  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# c  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
#
#   start station name
# b           Grand St
# c    McGinley Square

# %%
new_data.loc[['a','b','c'],'starttime':'start station name']
# loc need names of row and columns
# Out:
#              starttime             stoptime  start station id  \
# a  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# c  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
#
#   start station name
# a         Harborside
# b           Grand St
# c    McGinley Square

# %%
# for column also use zero indexing

#  custome indexiing is not posible

new_data.iloc[[1,3,4],["starttime","stoptime"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/1089551754.py in <module>
#       3 #  custome indexiing is not posible
#       4
# ----> 5 new_data.iloc[[1,3,4],["starttime","stoptime"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
# ...

# %%
new_data.iloc[[0,1,3,4],1:4]
# Out:
#              starttime             stoptime  start station id
# a  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# b  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# d  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# e  2018-05-01 04:27:12  2018-05-01 04:32:16              3207

# %%
# how to add and delete the daata

import pandas as pd
df=pd.read_csv('datasets/international_org.csv')
df
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %%
df["Headquater"]
# Out:
# 0          Rome
# 1     The Hague
# 2    Washington
# 3         Paris
# 4      New York
# 5    Washington
# Name: Headquater, dtype: object

# %%
df['Location']='Bengaluru'

# %%
df[df["Location"]=='Bengaluru']
# Out:
#   Organization Name  Headquater   Location
# 0               FAO        Rome  Bengaluru
# 1               ICJ   The Hague  Bengaluru
# 2               IMF  Washington  Bengaluru
# 3            UNESCO       Paris  Bengaluru
# 4               UNO    New York  Bengaluru
# 5        World Bank  Washington  Bengaluru

# %%
df
# Out:
#   Organization Name  Headquater   Location
# 0               FAO        Rome  Bengaluru
# 1               ICJ   The Hague  Bengaluru
# 2               IMF  Washington  Bengaluru
# 3            UNESCO       Paris  Bengaluru
# 4               UNO    New York  Bengaluru
# 5        World Bank  Washington  Bengaluru

# %%
df["Headquater"]="Banglore"
df

# all the dat od=f Headquater changed to given value

# make sure the column is not present
# Out:
#   Organization Name Headquater Location
# 0               FAO   Banglore     Banh
# 1               ICJ   Banglore     kera
# 2               IMF   Banglore      dfg
# 3            UNESCO   Banglore      Mjm
# 4               UNO   Banglore       er
# 5        World Bank   Banglore      asd

# %%
# len must same
df["Location"]=["Banh","kera","dfg","Mjm","er"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/535232838.py in <module>
#       1 # len must same
# ----> 2 df["Location"]=["Banh","kera","dfg","Mjm","er"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# ...

# %%
df["Location"]=["Banh","kera","dfg","Mjm","qw","er"]
df
# Out:
#   Organization Name Headquater Location
# 0               FAO   Banglore     Banh
# 1               ICJ   Banglore     kera
# 2               IMF   Banglore      dfg
# 3            UNESCO   Banglore      Mjm
# 4               UNO   Banglore       qw
# 5        World Bank   Banglore       er

# %%
df.rename(columns={'Headquater':'asd'})
# Out:
#   Organization Name       asd Location
# 0               FAO  Banglore     Banh
# 1               ICJ  Banglore     kera
# 2               IMF  Banglore      dfg
# 3            UNESCO  Banglore      Mjm
# 4               UNO  Banglore       qw
# 5        World Bank  Banglore       er

# %%
# rename
df.rename(columns={"Location":"abc"})
# Out:
#   Organization Name Headquater   abc
# 0               FAO   Banglore  Banh
# 1               ICJ   Banglore  kera
# 2               IMF   Banglore   dfg
# 3            UNESCO   Banglore   Mjm
# 4                as         as    as
# 5        World Bank   Banglore    er

# %%
df[df['Organization Name']=='FAO']
# Out:
#   Organization Name     abcd     asdf      abc Headquater Location
# 0               FAO  default  default  default   Banglore     Banh

# %%
df['Location'][4]='gas'

# %%
df['Headquater']='Banglore'

# %%
df['Headquater'][2]=12

# %%
df
# Out:
#   Organization Name     abcd     asdf      abc Headquater Location
# 0               FAO  default  default  default   Banglore     Banh
# 1               ICJ  default  default  default   Banglore     kera
# 2               IMF  default     Bang  default         12      dfg
# 3            UNESCO  default     lore  default   Banglore      Mjm
# 4                as  default       ke  default   Banglore      gas
# 5        World Bank  default       ra  default   Banglore      qas

# %%
dir(df)
# Out:
# ['Headquater',
#  'Location',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
# add a column at specific location
df.insert(1,"abcd","default")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/4059360867.py in <module>
#       1 # add a column at specific location
# ----> 2 df.insert(1,"abcd","default")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert abcd, already exists

# %%
df.insert(2,'asdf',['default',"default","Bang","lore","ke","ra"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/295628715.py in <module>
# ----> 1 df.insert(2,'asdf',['default',"default","Bang","lore","ke","ra"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert asdf, already exists

# %%
df
# Out:
#   Organization Name     abcd     asdf      abc Headquater Location
# 0               FAO  default  default  default   Banglore     Banh
# 1               ICJ  default  default  default   Banglore     kera
# 2               IMF  default     Bang  default         12      dfg
# 3            UNESCO  default     lore  default   Banglore      Mjm
# 4                as  default       ke  default   Banglore      gas
# 5        World Bank  default       ra  default   Banglore      qas

# %%
## Accessing the single value from the col

df["Headquater"][1]='fcs'
df
# Out:
#   Organization Name     abcd     asdf      abc Headquater Location
# 0               FAO  default  default  default   Banglore     Banh
# 1               ICJ  default  default  default        fcs     kera
# 2               IMF  default     Bang  default        qwe      dfg
# 3            UNESCO  default     lore  default   Banglore      Mjm
# 4                as  default       ke  default   Banglore      gas
# 5        World Bank  default       ra  default   Banglore      qas

# %%
df["Headquater"][2]
# Out:
# 'qwe'

# %%
df.drop(columns="abc",inplace=True)

# %%
# returns new obj
# df.drop(columns=["Headquater","sad","asdd"])

# %%
# it do not save untill you use var assign

# %%
# if you want to change in existing the 
# inplace=True
df.drop(columns=["abcd"],inplace=True)

# Changes will stored in same obj
# to save memory

# %%
df
# Out:
#   Organization Name     asdf Headquater Location
# 0               FAO  default   Banglore     Banh
# 1               ICJ  default        fcs     kera
# 2               IMF     Bang        qwe      dfg
# 3            UNESCO     lore   Banglore      Mjm
# 4                as       ke   Banglore      gas
# 5        World Bank       ra   Banglore      qas

# %%
# want to add new data

df[0]=["abcd",'s','d','g','e','w']
df
# Out:
#   Organization Name     asdf Headquater Location     0
# 0               FAO  default   Banglore     Banh  abcd
# 1               ICJ  default        fcs     kera     s
# 2               IMF     Bang        qwe      dfg     d
# 3            UNESCO     lore   Banglore      Mjm     g
# 4                as       ke   Banglore      gas     e
# 5        World Bank       ra   Banglore      qas     w

# %% [markdown]
# if you want to add new row make sure row not present

# %%
df.loc[-1]=["a",'s','d','g','e','w']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/3300575542.py in <module>
# ----> 1 df.loc[-1]=["a",'s','d','g','e','w']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# ...

# %%
# how to make -1 index to 6th index

df.index= df.index+1
df
# Out:
#   Organization Name     asdf Headquater Location     0
# 2               FAO  default   Banglore     Banh  abcd
# 3               ICJ  default        fcs     kera     s
# 4               IMF     Bang        qwe      dfg     d
# 5            UNESCO     lore   Banglore      Mjm     g
# 6                as       ke   Banglore      gas     e
# 7        World Bank       ra   Banglore      qas     w

# %%
df
# Out:
#   Organization Name     asdf Headquater Location     0
# 2               FAO  default   Banglore     Banh  abcd
# 3               ICJ  default        fcs     kera     s
# 4               IMF     Bang        qwe      dfg     d
# 5            UNESCO     lore   Banglore      Mjm     g
# 6                as       ke   Banglore      gas     e
# 7        World Bank       ra   Banglore      qas     w

# %%
df.loc[len(df)+1]=['xyz']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KIRANS~1\AppData\Local\Temp/ipykernel_7900/3562294957.py in <module>
# ----> 1 df.loc[len(df)+1]=['xyz']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1728         if take_split_path:
#    1729             # We have to operate column-wise
# -> 1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
#    1732             self._setitem_single_block(indexer, value, name)
#
# ...

# %%
df.drop(index=[3])
# Out:
#   Organization Name     asdf Headquater Location     0
# 2               FAO  default   Banglore     Banh  abcd
# 4               IMF     Bang        qwe      dfg     d
# 5            UNESCO     lore   Banglore      Mjm     g
# 6                as       ke   Banglore      gas     e
# 7        World Bank       ra   Banglore      qas     w

# %%
# sorting

# %%
df.sort_index(ascending=False)

# %%
df.sort_values(by=['Headquater'])

# %%
df.sort_values(by=['Headquater','Organization Name'])
